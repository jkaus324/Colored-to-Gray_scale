# %% [markdown]
# <a href="https://colab.research.google.com/github/jkaus324/Colored-to-Gray_scale/blob/main/Colored_Image_to_GRAY_scale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rgb2gray
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
from io import BytesIO
import requests

# %%
red = Image.new('RGB',(10,10),color = (255,0,0))

# %%
from skimage.color import rgb2gray
from skimage import data
img = data.astronaut()
img
img_gray = rgb2gray(img)

plt.imshow(img_gray, cmap='gray')
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,10))
axes[0].imshow(img)
axes[1].imshow(rgb2gray(img), cmap='gray')
plt.show();
